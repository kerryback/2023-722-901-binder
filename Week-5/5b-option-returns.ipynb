# %%
import yfinance as yf
import numpy as np
import plotly.express as px

tick = yf.Ticker('aapl')

# %%
tick.history().iloc[-1].round(2)
# Out:
# Open                 153.56
# High                 154.54
# Low                  150.23
# Close                150.59
# Volume          53755100.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2023-03-09 00:00:00-05:00, dtype: float64

# %%
df = tick.option_chain("2023-03-17").calls
df = df.set_index("strike")
df.iloc[:,2:5].loc[130:170]
# Out:
#         lastPrice  bid  ask
# strike
# 130.0       20.76  0.0  0.0
# 135.0       16.15  0.0  0.0
# 138.0       12.60  0.0  0.0
# 139.0       12.20  0.0  0.0
# 140.0       11.10  0.0  0.0
# 141.0       10.50  0.0  0.0
# 142.0        9.37  0.0  0.0
# 143.0        8.45  0.0  0.0
# 144.0        7.70  0.0  0.0
# 145.0        6.82  0.0  0.0
# 146.0        5.98  0.0  0.0
# 147.0        5.25  0.0  0.0
# 148.0        4.55  0.0  0.0
# 149.0        3.90  0.0  0.0
# 150.0        3.25  0.0  0.0
# 152.5        1.99  0.0  0.0
# 155.0        1.09  0.0  0.0
# 157.5        0.54  0.0  0.0
# 160.0        0.25  0.0  0.0
# 162.5        0.12  0.0  0.0
# 165.0        0.07  0.0  0.0
# 167.5        0.05  0.0  0.0
# 170.0        0.03  0.0  0.0

# %%
df = tick.option_chain("2023-03-17").puts
df = df.set_index("strike")
df.iloc[:,2:5].loc[130:170]
# Out:
#         lastPrice  bid  ask
# strike
# 130.0        0.05  0.0  0.0
# 135.0        0.12  0.0  0.0
# 138.0        0.20  0.0  0.0
# 139.0        0.28  0.0  0.0
# 140.0        0.33  0.0  0.0
# 141.0        0.42  0.0  0.0
# 142.0        0.52  0.0  0.0
# 143.0        0.63  0.0  0.0
# 144.0        0.79  0.0  0.0
# 145.0        0.98  0.0  0.0
# 146.0        1.19  0.0  0.0
# 147.0        1.44  0.0  0.0
# 148.0        1.74  0.0  0.0
# 149.0        2.13  0.0  0.0
# 150.0        2.53  0.0  0.0
# 152.5        3.75  0.0  0.0
# 155.0        5.35  0.0  0.0
# 157.5        7.00  0.0  0.0
# 160.0        9.40  0.0  0.0
# 162.5       11.80  0.0  0.0
# 165.0       14.25  0.0  0.0
# 167.5       15.10  0.0  0.0
# 170.0       19.60  0.0  0.0
